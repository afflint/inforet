# %% [markdown]
# # Vocabulary
# - **Task**: implement different strategies to tokenize and normalize text in order to weight token relevance.
# - **Input**: raw text
# - **Output**: a list of tokens for each text
#
# ### Main steps
# 0. Language detection
# 1. Tokenization
# 2. Case, punctuation, stopwords
# 3. Normalization

# %%
import json
import pandas as pd

# %%
dataset_file = '../data/wiki_dataset.json'
with open(dataset_file, 'r') as infile:
    dataset = json.load(infile)
docs = dataset['docs']
queries = dataset['queries']

# %%
T = docs[10]

# %%
T
# Out:
# 'Owen Underhill (born January 26, 1954) is a Canadian composer, flutist and conductor based in Vancouver. He is currently a professor of music at Simon Fraser University. He has been an active contributor to the new music scene on the West Coast, as a flutist, as co-music director of Western Front New Music (1982-3), as the artistic director (1987–2000) of the Vancouver New Music Society, and as a conductor in Magnetic Band and the Turning Point Ensemble, for which he is also currently the Artistic Co-Director.'

# %% [markdown]
# ## Language detection
# Many options, see for example [langdetect](https://pypi.org/project/langdetect)

# %%
from langdetect import detect, detect_langs

# %%
L = "Testo che mescola English words con testo italiano."

# %% [markdown]
#  This shows how models trained mainly on English may be unbalanced

# %%
print(detect_langs(L))
print(detect(L))
# Out:
# [en:0.8571393792360524, it:0.14285978965718393]
# en

# %% [markdown]
# The purpose of language detection is to use it when dealing with multilanguage corpora because some of the vocabulary building operations may be language dependant (e.g., lemmatization)

# %% [markdown]
# ## Tokenization

# %%
from nltk.tokenize import RegexpTokenizer

# %%
pattern = '\w+|\$[\d\.]+|\S+'
tokenizer = RegexpTokenizer(pattern)

# %%
text = docs[10]
tokens = tokenizer.tokenize(text)

# %%
print(text)
# Out:
# Owen Underhill (born January 26, 1954) is a Canadian composer, flutist and conductor based in Vancouver. He is currently a professor of music at Simon Fraser University. He has been an active contributor to the new music scene on the West Coast, as a flutist, as co-music director of Western Front New Music (1982-3), as the artistic director (1987–2000) of the Vancouver New Music Society, and as a conductor in Magnetic Band and the Turning Point Ensemble, for which he is also currently the Artistic Co-Director.

# %%
print(tokens)
# Out:
# ['Owen', 'Underhill', '(born', 'January', '26', ',', '1954', ')', 'is', 'a', 'Canadian', 'composer', ',', 'flutist', 'and', 'conductor', 'based', 'in', 'Vancouver', '.', 'He', 'is', 'currently', 'a', 'professor', 'of', 'music', 'at', 'Simon', 'Fraser', 'University', '.', 'He', 'has', 'been', 'an', 'active', 'contributor', 'to', 'the', 'new', 'music', 'scene', 'on', 'the', 'West', 'Coast', ',', 'as', 'a', 'flutist', ',', 'as', 'co', '-music', 'director', 'of', 'Western', 'Front', 'New', 'Music', '(1982-3),', 'as', 'the', 'artistic', 'director', '(1987–2000)', 'of', 'the', 'Vancouver', 'New', 'Music', 'Society', ',', 'and', 'as', 'a', 'conductor', 'in', 'Magnetic', 'Band', 'and', 'the', 'Turning', 'Point', 'Ensemble', ',', 'for', 'which', 'he', 'is', 'also', 'currently', 'the', 'Artistic', 'Co', '-Director.']

# %% [markdown]
# **Note**: when dealing with long texts, tokenization shold be performed sentence by sentence, exploiting <code>nltk.tokenize.sent_tokenize</code> before tokenization and normalization.

# %% [markdown]
# ## Case, punctuation and stopwords removal
# The importance of each step is relative to the size of the corpus and its sparseness

# %%
from string import punctuation
from nltk.corpus import stopwords

# %%
stopwords = set(stopwords.words('english'))

# %%
lower_tokens = lambda data: [x.lower() for x in data]
punct_tokens = lambda data: [x for x in data if x not in punctuation]
stop_tokens = lambda data: [x for x in data if x not in stopwords]

# %%
pipeline = [('lower', lower_tokens), ('punctuation', punct_tokens), ('stopwords', stop_tokens)]
current = tokens
print(T)
print(current, '\n')
for operation, f in pipeline:
    print(operation)
    current = f(current)
    print(current, '\n')
# Out:
# Owen Underhill (born January 26, 1954) is a Canadian composer, flutist and conductor based in Vancouver. He is currently a professor of music at Simon Fraser University. He has been an active contributor to the new music scene on the West Coast, as a flutist, as co-music director of Western Front New Music (1982-3), as the artistic director (1987–2000) of the Vancouver New Music Society, and as a conductor in Magnetic Band and the Turning Point Ensemble, for which he is also currently the Artistic Co-Director.
# ['Owen', 'Underhill', '(born', 'January', '26', ',', '1954', ')', 'is', 'a', 'Canadian', 'composer', ',', 'flutist', 'and', 'conductor', 'based', 'in', 'Vancouver', '.', 'He', 'is', 'currently', 'a', 'professor', 'of', 'music', 'at', 'Simon', 'Fraser', 'University', '.', 'He', 'has', 'been', 'an', 'active', 'contributor', 'to', 'the', 'new', 'music', 'scene', 'on', 'the', 'West', 'Coast', ',', 'as', 'a', 'flutist', ',', 'as', 'co', '-music', 'director', 'of', 'Western', 'Front', 'New', 'Music', '(1982-3),', 'as', 'the', 'artistic', 'director', '(1987–2000)', 'of', 'the', 'Vancouver', 'New', 'Music', 'Society', ',', 'and', 'as', 'a', 'conductor', 'in', 'Magnetic', 'Band', 'and', 'the', 'Turning', 'Point', 'Ensemble', ',', 'for', 'which', 'he', 'is', 'also', 'currently', 'the', 'Artistic', 'Co', '-Director.']
#
# lower
# ['owen', 'underhill', '(born', 'january', '26', ',', '1954', ')', 'is', 'a', 'canadian', 'composer', ',', 'flutist', 'and', 'conductor', 'based', 'in', 'vancouver', '.', 'he', 'is', 'currently', 'a', 'professor', 'of', 'music', 'at', 'simon', 'fraser', 'university', '.', 'he', 'has', 'been', 'an', 'active', 'contributor', 'to', 'the', 'new', 'music', 'scene', 'on', 'the', 'west', 'coast', ',', 'as', 'a', 'flutist', ',', 'as', 'co', '-music', 'director', 'of', 'western', 'front', 'new', 'music', '(1982-3),', 'as', 'the', 'artistic', 'director', '(1987–2000)', 'of', 'the', 'vancouver', 'new', 'music', 'society', ',', 'and', 'as', 'a', 'conductor', 'in', 'magnetic', 'band', 'and', 'the', 'turning', 'point', 'ensemble', ',', 'for', 'which', 'he', 'is', 'also', 'currently', 'the', 'artistic', 'co', '-director.']
#
# punctuation
# ['owen', 'underhill', '(born', 'january', '26', '1954', 'is', 'a', 'canadian', 'composer', 'flutist', 'and', 'conductor', 'based', 'in', 'vancouver', 'he', 'is', 'currently', 'a', 'professor', 'of', 'music', 'at', 'simon', 'fraser', 'university', 'he', 'has', 'been', 'an', 'active', 'contributor', 'to', 'the', 'new', 'music', 'scene', 'on', 'the', 'west', 'coast', 'as', 'a', 'flutist', 'as', 'co', '-music', 'director', 'of', 'western', 'front', 'new', 'music', '(1982-3),', 'as', 'the', 'artistic', 'director', '(1987–2000)', 'of', 'the', 'vancouver', 'new', 'music', 'society', 'and', 'as', 'a', 'conductor', 'in', 'magnetic', 'band', 'and', 'the', 'turning', 'point', 'ensemble', 'for', 'which', 'he', 'is', 'also', 'currently', 'the', 'artistic', 'co', '-director.']
#
# stopwords
# ['owen', 'underhill', '(born', 'january', '26', '1954', 'canadian', 'composer', 'flutist', 'conductor', 'based', 'vancouver', 'currently', 'professor', 'music', 'simon', 'fraser', 'university', 'active', 'contributor', 'new', 'music', 'scene', 'west', 'coast', 'flutist', 'co', '-music', 'director', 'western', 'front', 'new', 'music', '(1982-3),', 'artistic', 'director', '(1987–2000)', 'vancouver', 'new', 'music', 'society', 'conductor', 'magnetic', 'band', 'turning', 'point', 'ensemble', 'also', 'currently', 'artistic', 'co', '-director.']

# %% [markdown]
# ## Normalization

# %% [markdown]
# ### Stemming

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
stemmer = SnowballStemmer('english')

# %%
print([stemmer.stem(x) for x in current])
# Out:
# ['owen', 'underhil', '(born', 'januari', '26', '1954', 'canadian', 'compos', 'flutist', 'conductor', 'base', 'vancouv', 'current', 'professor', 'music', 'simon', 'fraser', 'univers', 'activ', 'contributor', 'new', 'music', 'scene', 'west', 'coast', 'flutist', 'co', '-music', 'director', 'western', 'front', 'new', 'music', '(1982-3),', 'artist', 'director', '(1987–2000)', 'vancouv', 'new', 'music', 'societi', 'conductor', 'magnet', 'band', 'turn', 'point', 'ensembl', 'also', 'current', 'artist', 'co', '-director.']

# %% [markdown]
# ### Lemmatization with WordNet

# %%
from nltk.corpus import wordnet as wn

# %%
syns = wn.synsets('group')

# %% [markdown]
# #### Problem 1: word sense disambiguation

# %%
for syn in syns:
    print(syn, syn.definition())
# Out:
# Synset('group.n.01') any number of entities (members) considered as a unit
# Synset('group.n.02') (chemistry) two or more atoms bound together as a single unit and forming part of a molecule
# Synset('group.n.03') a set that is closed, associative, has an identity element and every element has an inverse
# Synset('group.v.01') arrange into a group or groups
# Synset('group.v.02') form a group or group together

# %% [markdown]
# #### Problem 2: choice of lemma

# %%
for syn in syns:
    print(syn, [lemma.name() for lemma in syn.lemmas()])
# Out:
# Synset('group.n.01') ['group', 'grouping']
# Synset('group.n.02') ['group', 'radical', 'chemical_group']
# Synset('group.n.03') ['group', 'mathematical_group']
# Synset('group.v.01') ['group']
# Synset('group.v.02') ['group', 'aggroup']

# %% [markdown]
# ### Naive strategy

# %%
def wnlemma(word):
    try:
        s = wn.synsets(word)[0]
        try:
            l = s.lemmas()[0].name()
        except IndexError:
            return word
    except IndexError:
        return word
    return l

# %%
lemma_tokens = lambda data: [wnlemma(x) for x in data]

# %%
print(current)
print(lemma_tokens(current))
# Out:
# ['owen', 'underhill', '(born', 'january', '26', '1954', 'canadian', 'composer', 'flutist', 'conductor', 'based', 'vancouver', 'currently', 'professor', 'music', 'simon', 'fraser', 'university', 'active', 'contributor', 'new', 'music', 'scene', 'west', 'coast', 'flutist', 'co', '-music', 'director', 'western', 'front', 'new', 'music', '(1982-3),', 'artistic', 'director', '(1987–2000)', 'vancouver', 'new', 'music', 'society', 'conductor', 'magnetic', 'band', 'turning', 'point', 'ensemble', 'also', 'currently', 'artistic', 'co', '-director.']
# ['Owen', 'underhill', '(born', 'January', 'twenty-six', '1954', 'Canadian', 'composer', 'flutist', 'conductor', 'establish', 'Vancouver', 'presently', 'professor', 'music', 'Simon', 'fraser', 'university', 'active_agent', 'subscriber', 'new', 'music', 'scene', 'West', 'seashore', 'flutist', 'carbon_monoxide', '-music', 'director', 'Western', 'front', 'new', 'music', '(1982-3),', 'artistic', 'director', '(1987–2000)', 'Vancouver', 'new', 'music', 'society', 'conductor', 'magnetic', 'set', 'turn', 'point', 'ensemble', 'besides', 'presently', 'artistic', 'carbon_monoxide', '-director.']

# %% [markdown]
# ### Exercize: find a better strategy for word sense disambiguation using WordNet

# %% [markdown]
# # Approaches based on language modeling: Spacy

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(T)

# %% [markdown]
# ### Sentence parsing

# %%
for s in doc.sents:
    print(s)
# Out:
# Owen Underhill (born January 26, 1954) is a Canadian composer, flutist and conductor based in Vancouver.
# He is currently a professor of music at Simon Fraser University.
# He has been an active contributor to the new music scene on the West Coast, as a flutist, as co-music director of Western Front New Music (1982-3), as the artistic director (1987–2000) of the Vancouver New Music Society, and as a conductor in Magnetic Band and the Turning Point Ensemble, for which he is also currently the Artistic Co-Director.

# %% [markdown]
# ## Tokenization

# %%
fields = ['text', 'lemma', 'pos', 'tag', 'dep', 'shape', 'alpha', 'stopwords']
tks = []
for token in list(doc.sents)[0]:
    data = [token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop]
    tks.append(dict([(fields[i], x) for i, x in enumerate(data)]))

# %%
df = pd.DataFrame(tks)

# %%
df
# Out:
#          text      lemma    pos    tag       dep  shape  alpha  stopwords
# 0        Owen       Owen  PROPN    NNP  compound   Xxxx   True      False
# 1   Underhill  Underhill  PROPN    NNP     nsubj  Xxxxx   True      False
# 2           (          (  PUNCT  -LRB-     punct      (  False      False
# 3        born       bear   VERB    VBN       acl   xxxx   True      False
# 4     January    January  PROPN    NNP  npadvmod  Xxxxx   True      False
# 5          26         26    NUM     CD    nummod     dd  False      False
# 6           ,          ,  PUNCT      ,     punct      ,  False      False
# 7        1954       1954    NUM     CD    nummod   dddd  False      False
# 8           )          )  PUNCT  -RRB-     punct      )  False      False
# 9          is         be   VERB    VBZ      ROOT     xx   True       True
# 10          a          a    DET     DT       det      x   True       True
# 11   Canadian   canadian    ADJ     JJ      amod  Xxxxx   True      False
# 12   composer   composer   NOUN     NN      attr   xxxx   True      False
# 13          ,          ,  PUNCT      ,     punct      ,  False      False
# 14    flutist    flutist   NOUN     NN      conj   xxxx   True      False
# 15        and        and  CCONJ     CC        cc    xxx   True       True
# 16  conductor  conductor   NOUN     NN      conj   xxxx   True      False
# 17      based       base   VERB    VBN       acl   xxxx   True      False
# 18         in         in    ADP     IN      prep     xx   True       True
# 19  Vancouver  Vancouver  PROPN    NNP      pobj  Xxxxx   True      False
# 20          .          .  PUNCT      .     punct      .  False      False

# %% [markdown]
# ## Case, punctuation and stopwords removal

# %%
punct_tokens = lambda data: [x for x in data if x.pos_ not in ['PUNCT', 'SPACE']]
stop_tokens = lambda data: [x for x in data if not x.is_stop]

# %%
spacy_tokens = stop_tokens(punct_tokens(nlp(T)))

# %%
print(spacy_tokens)
# Out:
# [Owen, Underhill, born, January, 26, 1954, Canadian, composer, flutist, conductor, based, Vancouver, currently, professor, music, Simon, Fraser, University, active, contributor, new, music, scene, West, Coast, flutist, co, -, music, director, Western, New, Music, 1982, -, 3, artistic, director, 1987–2000, Vancouver, New, Music, Society, conductor, Magnetic, Band, Turning, Point, Ensemble, currently, Artistic, Co, -, Director]

# %% [markdown]
# ## Normalization

# %%
spacy_lemma = lambda data: [x.lemma_ for x in data]

# %%
print(spacy_lemma(spacy_tokens))
# Out:
# ['Owen', 'Underhill', 'bear', 'January', '26', '1954', 'canadian', 'composer', 'flutist', 'conductor', 'base', 'Vancouver', 'currently', 'professor', 'music', 'Simon', 'Fraser', 'University', 'active', 'contributor', 'new', 'music', 'scene', 'West', 'Coast', 'flutist', 'co', '-', 'music', 'director', 'western', 'New', 'Music', '1982', '-', '3', 'artistic', 'director', '1987–2000', 'Vancouver', 'New', 'Music', 'Society', 'conductor', 'Magnetic', 'Band', 'Turning', 'Point', 'ensemble', 'currently', 'Artistic', 'Co', '-', 'Director']

# %% [markdown]
# ### A look into dependencies and entities (more on this later on course)

# %%
from spacy import displacy

# %%
T = docs[1].strip()

# %%
displacy.render(nlp(T), style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Elections to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Rotherham Metropolitan Borough Council
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  were held on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     3 May 2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Labour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  party kept overall control of the council.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     One third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the council was up for election and no boundary changes were made. After the election, the composition of the council was: *Labour
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     54
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  *Conservative
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  *Others
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </div>

# %%
displacy.render(nlp(T), style='dep', options={'compact': True, 
                                              'collapse_phrases': True,
                                             'add_lemma': True})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="efdd4b551d364d70a13fe3592002ada6-0" class="displacy" width="5450" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Elections</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Rotherham Metropolitan Borough Council</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">were</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">held</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">3 May</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">2007.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">The Labour party</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">kept</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">overall control</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">the council.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">One third</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">the council</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">up</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">election</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">no boundary changes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">were</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">made.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">After</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">the election,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">the composition</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">the council</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">was:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">*Labour</

# %%
table = {'token': [], 'token dep': [], 'head': [], 'head pos': [], 'children': [], 'ancestors': []}
for token in nlp(T):
    table['token'].append(token.text)
    table['token dep'].append(token.dep_)
    table['head'].append(token.head.text)
    table['head pos'].append(token.head.pos_)
    table['children'].append(", ".join([child.text for child in token.children]))
    table['ancestors'].append(", ".join([a.text for a in token.ancestors]))
S = pd.DataFrame(table)

# %%
S
# Out:
#            token  token dep          head head pos  \
# 0      Elections  nsubjpass          held     VERB
# 1             to       prep     Elections     NOUN
# 2      Rotherham   compound       Council    PROPN
# 3   Metropolitan   compound       Council    PROPN
# 4        Borough   compound       Council    PROPN
# 5        Council       pobj            to      ADP
# 6           were    auxpass          held     VERB
# 7           held       ROOT          held     VERB
# 8             on       prep          held     VERB
# 9              3     nummod           May    PROPN
# 10           May       pobj            on      ADP
# 11          2007     nummod           May    PROPN
# 12             .      punct          held     VERB
# 13           The        det         party     NOUN
# 14        Labour   compound         party     NOUN
# 15         party      nsubj          kept     VERB
# 16          kept       ROOT          kept     VERB
# 17       overall       amod       control     NOUN
# 18       control       dobj          kept     VERB
# 19            of       prep       control     NOUN
# 20           the        det       council     NOUN
# 21       council       pobj            of      ADP
# 22             .      punct          kept     VERB
# 23           One     nummod         third     NOUN
# 24         third      nsubj           was     VERB
# 25            of       prep         third     NOUN
# 26           the        det       council     NOUN
# 27       council       pobj            of      ADP
# 28           was       ROOT           was     VERB
# 29            up       prep           was     VERB
# 30           for       prep            up      ADV
# 31      election       pobj           for      ADP
# 32           and         cc           was     VERB
# 33            no        det       changes     NOUN
# 34      boundary       amod       changes     NOUN
# 35       changes  nsubjpass          made     VERB
# 36          were    auxpass          made     VERB
# 37          made       conj           was     VERB
# 38             .      punct          made     VERB
# 39         After       prep           was     VERB
# 40           the        det      election     NOUN
# 41      election       pobj         After      ADP
# 42             ,      punct           was     VERB
# 43           the        det   composition     NOUN
# 44   composition      nsubj           was     VERB
# 45            of       prep   composition     NOUN
# 46           the        det       council     NOUN
# 47       council       pobj            of      ADP
# 48           was       ROOT           was     VERB
# 49             :      punct           was     VERB
# 50             *      punct        Labour     NOUN
# 51        Labour       ROOT        Labour     NOUN
# 52            54     nummod        Labour     NOUN
# 53             *      punct  Conservative    PROPN
# 54  Conservative       ROOT  Conservative    PROPN
# 55             7     nummod  Conservative    PROPN
# 56             *      punct        Others     NOUN
# 57        Others       ROOT        Others     NOUN
# 58             2     nummod        Others     NOUN
#
#                             children                      ancestors
# 0                                 to                           held
# 1                            Council                Elections, held
# 2                                      Council, to, Elections, held
# 3                                      Council, to, Elections, held
# 4                                      Council, to, Elections, held
# 5   Rotherham, Metropolitan, Borough            to, Elections, held
# 6                                                              held
# 7             Elections, were, on, .
# 8                                May                           held
# 9                                                     May, on, held
# 10                           3, 2007                       on, held
# 11                                                    May, on, held
# 12                                                             held
# 13                                                      party, kept
# 14                                                      party, kept
# 15                       The, Labour                           kept
# 16                 party, control, .
# 17                                                    control, kept
# 18                       overall, of                           kept
# 19                           council                  control, kept
# 20                                       council, of, control, kept
# 21                               the              of, control, kept
# 22                                                             kept
# 23                                                       third, was
# 24                           One, of                            was
# 25                           council                     third, was
# 26                                          council, of, third, was
# 27                               the                 of, third, was
# 28              third, up, and, made
# 29                               for                            was
# 30                          election                        up, was
# 31                                                     for, up, was
# 32                                                              was
# 33                                               changes, made, was
# 34                                               changes, made, was
# 35                      no, boundary                      made, was
# 36                                                        made, was
# 37                  changes, were, .                            was
# 38                                                        made, was
# 39                          election                            was
# 40                                             election, After, was
# 41                               the                     After, was
# 42                                                              was
# 43                                                 composition, was
# 44                           the, of                            was
# 45                           council               composition, was
# 46                                    council, of, composition, was
# 47                               the           of, composition, was
# 48          After, ,, composition, :
# 49                                                              was
# 50                                                           Labour
# 51                             *, 54
# 52                                                           Labour
# 53                                                     Conservative
# 54                              *, 7
# 55                                                     Conservative
# 56                                                           Others
# 57                              *, 2
# 58                                                           Others
